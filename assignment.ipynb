# %%
# Data Science Notebook

# %%
## Introduction

This notebook covers basic data science concepts, including programming languages, libraries, tools, and some example code for arithmetic operations.

# %%
## Data Science Languages

- Python  
- R  
- SQL  
- Julia  
- Scala

# %%
## Data Science Libraries

- Pandas  
- NumPy  
- Matplotlib  
- Scikit-learn  
- TensorFlow  
- ggplot2

# %%
## Data Science Tools

| Tool           | Description                     |
|----------------|---------------------------------|
| Jupyter        | Interactive coding environment  |
| RStudio        | IDE for R                       |
| Apache Spark   | Big data processing             |
| TensorFlow     | Deep learning library           |
| VS Code        | General-purpose code editor     |

# %%
## Examples of Arithmetic Expressions

Below are examples of how to use arithmetic operations in Python.

# %%
# Multiply and add numbers
a = 5
b = 10
result = (a * b) + 20
print("The result is:", result)

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
print("Hours:", hours)

# %%
## Objectives

- Learn basic markdown in Jupyter  
- Practice arithmetic operations in Python  
- Understand data science tools and libraries  
- Convert values and work with simple code  
- Share work via GitHub

# %%
## Author

**Permjit Yadav**
